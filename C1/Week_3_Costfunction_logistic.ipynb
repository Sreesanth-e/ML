# %%
import sys
sys.path.append('../data')
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from plt_logistic_loss import  plt_logistic_cost, plt_two_logistic_loss_curves, plt_simple_example
from plt_logistic_loss import soup_bowl, plt_logistic_squared_error
plt.style.use('../data/deeplearning.mplstyle')

# %%
soup_bowl()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
x_train = np.array([0., 1, 2, 3, 4, 5],dtype=np.longdouble)
y_train = np.array([0,  0, 0, 1, 1, 1],dtype=np.longdouble)

# %%
plt_simple_example(x_train,y_train)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
plt.close('all')
plt_logistic_squared_error(x_train,y_train)
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
plt_two_logistic_loss_curves()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
plt.close('all')
plt_logistic_cost(x_train,y_train)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …
# array([[12.12, 11.38, 10.65, ...,  5.75,  5.93,  6.12],
#        [12.33, 11.6 , 10.87, ...,  5.54,  5.72,  5.91],
#        [12.56, 11.83, 11.09, ...,  5.34,  5.53,  5.71],
#        ...,
#        [21.49, 20.75, 20.02, ...,  0.6 ,  0.72,  0.84],
#        [21.74, 21.01, 20.27, ...,  0.52,  0.63,  0.75],
#        [22.  , 21.27, 20.53, ...,  0.43,  0.55,  0.67]], dtype=float64)

# %%
from lab_utils_common import  plot_data, sigmoid, dlc

# %%
X_train = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train = np.array([0, 0, 0, 1, 1, 1])

# %%
fig, ax = plt.subplots(1,1,figsize = (4,4))
plot_data(X_train,y_train,ax)
ax.axis([0,4,0,3.5])
# Out:
# (np.float64(0.0), np.float64(4.0), np.float64(0.0), np.float64(3.5))
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
def compute_cost_logistic(X,y,w,b):
    m = X.shape[0]
    cost = 0.0

    for i in range(m):
        z = np.dot(X[i],w) + b
        f_wb_i = sigmoid(z)
        cost += -y[i]*np.log(f_wb_i)- (1 - y[i])*np.log(1-f_wb_i)

    cost = cost/m
    return cost

# %%
w_tmp = np.array([1,1])
b_tmp = -3
print(compute_cost_logistic(X_train,y_train,w_tmp,b_tmp))
# Out:
# 0.36686678640551745

# %%
x0 = np.arange(0,6)

x1 = 3 - x0
x1_other = 4 - x0

fig , ax = plt.subplots(1,1 , figsize = (5,5))
ax.plot(x0,x1)
ax.plot(x0,x1_other)

plot_data(X_train,y_train,ax)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
w_array_1 = np.array([1,1])
b_array_1 = -3

w_array_2 = np.array([1,1])
b_array_2 = -4

print(compute_cost_logistic(X_train,y_train,w_array_1,b_array_1))
print(compute_cost_logistic(X_train,y_train,w_array_2,b_array_2))
# Out:
# 0.36686678640551745
# 0.5036808636748461
